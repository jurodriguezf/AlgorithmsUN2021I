# %% [markdown]
# Coursera certificate link: https://www.coursera.org/account/accomplishments/certificate/ZN45NGXRQYEN

# %% [markdown]
# Certificate screenshot:
#
# ![certificate.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# LinkedIn published certificate:
#
# ![linkedin certificate.jpg](data:image/jpeg;base64,...)
